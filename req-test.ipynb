# %%
import requests
import json

url = "https://taigatakahashi.com/page-data/collection/lot-7-denim/page-data.json"

response = requests.get(url)
data = response.json()

print(json.dumps(data, indent=4))
# Out:
# {
#     "componentChunkName": "component---src-templates-collection-jsx",
#     "path": "/collection/lot-7-denim/",
#     "result": {
#         "serverData": {
#             "data": {
#                 "collection": {
#                     "title": "Lot \u2116\u20097 Denim",
#                     "description": "",
#                     "seo": {
#                         "title": null,
#                         "description": null
#                     },
#                     "handle": "lot-7-denim",
#                     "products": {
#                         "pageInfo": {
#                             "hasNextPage": false,
#                             "endCursor": "eyJsYXN0X2lkIjo3ODg4OTE3MTY4Mjk0LCJsYXN0X3ZhbHVlIjoiW1N0b3JlIExpbWl0ZWRdIExPVC43MDMgREVOSU0gSkFDS0VUIEMuMTkyMCdTIn0="
#                         },
#                         "edges": [
#                             {
#                                 "node": {
#                                     "id": "gid://shopify/Product/7758794358950",
#                                     "title": "LOT.701 DENIM JACKET",
#                                     "handle": "lot-701-denim-jacket-core",
#                                     "description": "Taiga Takahashi's iconic denim jacket. This denim jacket is made of our original 100% organic cotton denim fabric woven on an old-style power loom in Okayama, Japan. This 3/1 left twill, light-ounce denim is made from U.S.-grown organic cotton and woven on an old-style power loom in Okayama, Japan. The denim fabric is slowly woven on an old-type power loom, also known as a shuttle loom, which can weave at only 1/10 to 1/20 the speed of modern looms, leaving the original unevenness of the cotton yarns and making the fabric uneven in a good sense. The warp yarn is indigo mixed with sulfide dye, which gives it a weathered green cast color. The core is dyed white by rope-dyeing. The weft yarn is a custom-made nep yarn dyed to a yellowish, yellowish color that evokes the passage of time. By using these two types of yarns, we arrived at Taiga Takahashi's original dark and deep indigo blue. The finishing touch is a shrink-proofing process called \"Sanforized. The fabric is a \"white ear\" selvedge denim fabric, and white ears are used on the front flap, the back of the cuffs, and in various other areas. In the 1940s, the use of decorative snap buttons instead of the traditional iron buttons was introduced, and other details began to change. The Art Deco style buttons and rivets used in those days were studied and reproduced in their original colors. Signature leather patches are made from mud-dyed leather patches from Amami-Oshima. Cotton 100% Model: 186cm size40 After washing, 2-3% shrinkage will occur.",
#                                     "availableForSale": true,
#                                     "title_jp": null,
#                                     "priceRange": {
#                                         "minVariantPrice": {
#                                             "amount": "50600.0",
#                                             "currencyCode": "JPY"
#                                         },
#                                         "maxVariantPrice": {
#                                             "amount": "50600.0",
#                                             "currencyCode": "JPY"
#                                         }
#                                     },
#                                     "featuredImage": {
#                                         "originalSrc": "https://cdn.shopify.com/s/files/1/0432/1168/6054/files/LOT.701DENIMJACKET-RAWINDIGO_1.jpg?v=1689745586",
#                                         "altText": null
#                                     },
#                                     "tags": [
#                                         "Denim",
#                                         "Online"
#                                     ],
#                                     "totalInventory": 16,
#                                     "options": [
#                                         {
#                                             "id": "gid://shopify/ProductOption/9928591933606",
#                                             "name": "SIZE",
#                                             "values": [
#                                                 "36",
#                                                 "38",
#                                                 "40",
#                                                 "42"
#                                             ]
#                                         },
#                                         {
#                                             "id": "gid://shopify/ProductOption/9928591966374",
#                                             "name": "COLOR",
#                                             "values": [
#                                                 "RAW INDIGO"
#                                             ]
#                                         }
#                                     ],
#                                     "variants": {
#                                         "edges": [
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/44262578782374",
#                                                     "title": "36 / RAW INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "36"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "RAW INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "50600.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": true,
#                                                     "sku": "1000000010077",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 4
#                                                 }
#                                             },
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/44262578815142",
#                                                     "title": "38 / RAW INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "38"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "RAW INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "50600.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": true,
#                                                     "sku": "1000000010084",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 5
#                                                 }
#                                             },
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/44262578847910",
#                                                     "title": "40 / RAW INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "40"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "RAW INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "50600.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": true,
#                                                     "sku": "1000000010091",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 3
#                                                 }
#                                             },
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/44717280133286",
#                                                     "title": "42 / RAW INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "42"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "RAW INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "50600.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": true,
#                                                     "sku": "1000000010275",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 4
#                                                 }
#                                             }
#                                         ]
#                                     },
#                                     "images": {
#                                         "edges": [
#                                             {
#                                                 "node": {
#                                                     "originalSrc": "https://cdn.shopify.com/s/files/1/0432/1168/6054/files/LOT.701DENIMJACKET-RAWINDIGO_1.jpg?v=1689745586",
#                                                     "altText": null
#                                                 }
#                                             }
#                                         ]
#                                     }
#                                 }
#                             },
#                             {
#                                 "node": {
#                                     "id": "gid://shopify/Product/8129041137830",
#                                     "title": "LOT.702 DENIM TROUSERS",
#                                     "handle": "lot-702-denim-trousers-core",
#                                     "description": "Taiga Takahashi's iconic wide silhouette selvage jeans are made from original denim fabric from Okayama, Japan. This 3/1 left twill, light-ounce denim is made of U.S.-grown organic cotton and woven on an old-style power loom in Okayama, Japan. The denim fabric is slowly woven on an old-type power loom, also known as a shuttle loom, which can weave at only 1/10 to 1/20 the speed of modern looms, leaving the original unevenness of the cotton yarns and making the fabric uneven in a good sense. The warp yarn is indigo mixed with sulfide dye, which gives it a weathered green cast color. The core is dyed white by rope-dyeing. The weft yarn is a custom-made nep yarn dyed to a yellowish, yellowish color that evokes the passage of time. By using these two types of yarns, we arrived at Taiga Takahashi's original dark and deep indigo blue. The finishing touch is a shrink-proofing process called \"Sanforized. The fabric is a \"white ear\" selvedge denim fabric, and the white ear is used in various places, including the back of the belt. In the 1940s, the use of decorative snap buttons instead of the traditional iron buttons was introduced, and other details began to change. The Art Deco style buttons and rivets used in those days were studied and reproduced in their original colors. Signature leather patches are made from mud-dyed leather patches from Amami-Oshima. Cotton 100% Model: 186cm size32 After washing, 2~3% shrinkage will occur.",
#                                     "availableForSale": true,
#                                     "title_jp": null,
#                                     "priceRange": {
#                                         "minVariantPrice": {
#                                             "amount": "39600.0",
#                                             "currencyCode": "JPY"
#                                         },
#                                         "maxVariantPrice": {
#                                             "amount": "39600.0",
#                                             "currencyCode": "JPY"
#                                         }
#                                     },
#                                     "featuredImage": {
#                                         "originalSrc": "https://cdn.shopify.com/s/files/1/0432/1168/6054/files/702_Font_ab2a891e-6191-4d42-ae89-73c173996308.jpg?v=1715413142",
#                                         "altText": null
#                                     },
#                                     "tags": [
#                                         "Denim",
#                                         "Online"
#                                     ],
#                                     "totalInventory": 5,
#                                     "options": [
#                                         {
#                                             "id": "gid://shopify/ProductOption/10356400947366",
#                                             "name": "SIZE",
#                                             "values": [
#                                                 "28",
#                                                 "30",
#                                                 "32",
#                                                 "34",
#                                                 "36"
#                                             ]
#                                         },
#                                         {
#                                             "id": "gid://shopify/ProductOption/10356400980134",
#                                             "name": "COLOR",
#                                             "values": [
#                                                 "RAW INDIGO"
#                                             ]
#                                         }
#                                     ],
#                                     "variants": {
#                                         "edges": [
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/45348055515302",
#                                                     "title": "28 / RAW INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "28"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "RAW INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "39600.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": true,
#                                                     "sku": "1000000010107",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 5
#                                                 }
#                                             },
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/45348055548070",
#                                                     "title": "30 / RAW INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "30"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "RAW INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "39600.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": false,
#                                                     "sku": "1000000010114",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 0
#                                                 }
#                                             },
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/45348055580838",
#                                                     "title": "32 / RAW INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "32"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "RAW INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "39600.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": false,
#                                                     "sku": "1000000010121",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 0
#                                                 }
#                                             },
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/45348055613606",
#                                                     "title": "34 / RAW INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "34"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "RAW INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "39600.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": false,
#                                                     "sku": "1000000010138",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 0
#                                                 }
#                                             },
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/45348055646374",
#                                                     "title": "36 / RAW INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "36"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "RAW INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "39600.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": false,
#                                                     "sku": "1000000010282",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 0
#                                                 }
#                                             }
#                                         ]
#                                     },
#                                     "images": {
#                                         "edges": [
#                                             {
#                                                 "node": {
#                                                     "originalSrc": "https://cdn.shopify.com/s/files/1/0432/1168/6054/files/702_Font_ab2a891e-6191-4d42-ae89-73c173996308.jpg?v=1715413142",
#                                                     "altText": null
#                                                 }
#                                             }
#                                         ]
#                                     }
#                                 }
#                             },
#                             {
#                                 "node": {
#                                     "id": "gid://shopify/Product/7759514239142",
#                                     "title": "LOT.703 DENIM JACKET C.1920'S",
#                                     "handle": "lot-703-denim-jacket-c-1920s-raw-indigo23aw",
#                                     "description": "1920's denim jacket, an iconic item of Taiga Takahashi. Taiga Takahashi liked denim brands called \"store\" more than Levi's. Especially J.C. Penny, which had a brand called Foremost. In particular, J.C. Penny, which had a brand called Foremost, started making denim that imitated Levi's in the 1920s, and gradually developed designs with originality. After collecting these denim items, we felt their will to differentiate themselves from Levi's through trial and error in every detail, and Taiga Takahashi's original denim was born. This 3/1 left twill, light-ounce denim is made from U.S.-grown organic cotton and woven on an old-style power loom in Okayama. The denim fabric is slowly woven on an old-type power loom, also known as a shuttle loom, which can weave at only 1/10 to 1/20 the speed of modern looms, leaving the original unevenness of the cotton yarns and making the fabric uneven in a good sense. The warp yarn is indigo mixed with sulfide dye, which gives it a weathered green cast color. The core is dyed white by rope-dyeing. The weft yarn is a custom-made nep yarn dyed to a yellowish, yellowish color that evokes the passage of time. By using these two types of yarns, we arrived at Taiga Takahashi's original dark and deep indigo blue. The finishing touch is a shrink-proofing process called \"Sanforized. The fabric is a \"white ear\" selvedge denim fabric, and the white ear is used on the front flap, the back of the cuffs, and in various other areas. The jacket has a patch pocket on one side, and is simply constructed with only one stitch each to fasten the pleats on the front. The silhouette is flat, with straight sleeves and no sloping shoulder line. All the details are constructed in exactly the same way as in the 1920s. Signature leather patches are made from mud-dyed leather patches from Amami-Oshima. Cotton 100% Model: 186cm size40 After washing, 2~3% shrinkage will occur.",
#                                     "availableForSale": false,
#                                     "title_jp": null,
#                                     "priceRange": {
#                                         "minVariantPrice": {
#                                             "amount": "52800.0",
#                                             "currencyCode": "JPY"
#                                         },
#                                         "maxVariantPrice": {
#                                             "amount": "52800.0",
#                                             "currencyCode": "JPY"
#                                         }
#                                     },
#                                     "featuredImage": {
#                                         "originalSrc": "https://cdn.shopify.com/s/files/1/0432/1168/6054/files/LOT.703DENIMJACKETC.1930_S-RAWINDIGO_1_c50d461a-b39c-4a02-bfac-bd10640dc3af.jpg?v=1689748057",
#                                         "altText": null
#                                     },
#                                     "tags": [
#                                         "Denim",
#                                         "Online"
#                                     ],
#                                     "totalInventory": 0,
#                                     "options": [
#                                         {
#                                             "id": "gid://shopify/ProductOption/9929406152870",
#                                             "name": "SIZE",
#                                             "values": [
#                                                 "36",
#                                                 "38",
#                                                 "40",
#                                                 "42"
#                                             ]
#                                         },
#                                         {
#                                             "id": "gid://shopify/ProductOption/9929406185638",
#                                             "name": "COLOR",
#                                             "values": [
#                                                 "RAW INDIGO"
#                                             ]
#                                         }
#                                     ],
#                                     "variants": {
#                                         "edges": [
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/44268326355110",
#                                                     "title": "36 / RAW INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "36"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "RAW INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "52800.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": false,
#                                                     "sku": "1000000010145",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 0
#                                                 }
#                                             },
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/44268326387878",
#                                                     "title": "38 / RAW INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "38"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "RAW INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "52800.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": false,
#                                                     "sku": "1000000010152",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 0
#                                                 }
#                                             },
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/44268326420646",
#                                                     "title": "40 / RAW INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "40"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "RAW INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "52800.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": false,
#                                                     "sku": "1000000010169",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 0
#                                                 }
#                                             },
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/44717282885798",
#                                                     "title": "42 / RAW INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "42"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "RAW INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "52800.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": false,
#                                                     "sku": "1000000010299",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 0
#                                                 }
#                                             }
#                                         ]
#                                     },
#                                     "images": {
#                                         "edges": [
#                                             {
#                                                 "node": {
#                                                     "originalSrc": "https://cdn.shopify.com/s/files/1/0432/1168/6054/files/LOT.703DENIMJACKETC.1930_S-RAWINDIGO_1_c50d461a-b39c-4a02-bfac-bd10640dc3af.jpg?v=1689748057",
#                                                     "altText": null
#                                                 }
#                                             }
#                                         ]
#                                     }
#                                 }
#                             },
#                             {
#                                 "node": {
#                                     "id": "gid://shopify/Product/7888917069990",
#                                     "title": "LOT.703 DENIM JACKET C.1920'S",
#                                     "handle": "lot-703-denim-jacket-c-1920s-damaged-indigo24ss",
#                                     "description": "The denim jacket is based on Taiga Takahashi's iconic LOT.703 Denim Jacket c.1920's, added with distressed finish. Salt-shrink process is used in addition to the standard distressed finish to create worn-out details like wrinkles and whiskers, which make it look as if it was worn from a raw denim state. The rusty and weathered buttons, rivets, and buckles establish a distinctive presence. COTTON 100% Model: 186cm size42 This product has been specially processed to rust the potains, rivets, and buckles. Therefore, please be careful when wearing this product, as there is a possibility that the rust may adhere to other clothing or pugs due to friction.Please be careful when wearing the product, as there may be rust on the product, which is a characteristic of the product.",
#                                     "availableForSale": true,
#                                     "title_jp": null,
#                                     "priceRange": {
#                                         "minVariantPrice": {
#                                             "amount": "86900.0",
#                                             "currencyCode": "JPY"
#                                         },
#                                         "maxVariantPrice": {
#                                             "amount": "86900.0",
#                                             "currencyCode": "JPY"
#                                         }
#                                     },
#                                     "featuredImage": {
#                                         "originalSrc": "https://cdn.shopify.com/s/files/1/0432/1168/6054/files/Lot.703DAMAGEDINDIGO01.jpg?v=1709716812",
#                                         "altText": null
#                                     },
#                                     "tags": [
#                                         "Denim",
#                                         "Online"
#                                     ],
#                                     "totalInventory": 1,
#                                     "options": [
#                                         {
#                                             "id": "gid://shopify/ProductOption/10071865819302",
#                                             "name": "SIZE",
#                                             "values": [
#                                                 "36",
#                                                 "38",
#                                                 "40",
#                                                 "42"
#                                             ]
#                                         },
#                                         {
#                                             "id": "gid://shopify/ProductOption/10071865852070",
#                                             "name": "COLOR",
#                                             "values": [
#                                                 "DAMAGED INDIGO"
#                                             ]
#                                         }
#                                     ],
#                                     "variants": {
#                                         "edges": [
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/44676306600102",
#                                                     "title": "36 / DAMAGED INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "36"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "DAMAGED INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "86900.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": false,
#                                                     "sku": "1000000018103",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 0
#                                                 }
#                                             },
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/44676306632870",
#                                                     "title": "38 / DAMAGED INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "38"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "DAMAGED INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "86900.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
#                                                     "availableForSale": false,
#                                                     "sku": "1000000018110",
#                                                     "weight": 0,
#                                                     "weightUnit": "POUNDS",
#                                                     "quantityAvailable": 0
#                                                 }
#                                             },
#                                             {
#                                                 "node": {
#                                                     "id": "gid://shopify/ProductVariant/44676306665638",
#                                                     "title": "40 / DAMAGED INDIGO",
#                                                     "selectedOptions": [
#                                                         {
#                                                             "name": "SIZE",
#                                                             "value": "40"
#                                                         },
#                                                         {
#                                                             "name": "COLOR",
#                                                             "value": "DAMAGED INDIGO"
#                                                         }
#                                                     ],
#                                                     "priceV2": {
#                                                         "amount": "86900.0",
#                                                         "currencyCode": "JPY"
#                                                     },
#                                                     "compareAtPriceV2": null,
# ...
#                             }
#                         ]
#                     },
#                     {
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "The arrival of products may be delayed due to weather, traffic conditions, or regional factors.",
#                                 "_key": "1060d660e61d"
#                             }
#                         ],
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "fba3c0f73633",
#                         "markDefs": []
#                     },
#                     {
#                         "_key": "162da9e1c3ab",
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "Items ordered separately cannot be shipped together.\nAll items will be shipped in units of the order.",
#                                 "_key": "92066ec379c2"
#                             }
#                         ],
#                         "_type": "block",
#                         "style": "normal"
#                     },
#                     {
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "0836a088e02e",
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "We do not offer gift wrapping.",
#                                 "_key": "05d70f155e3b"
#                             }
#                         ]
#                     },
#                     {
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "Shipping fee in Japan: \u00a5660 (tax included)\nHowever, if the total amount of your purchase is over \u00a530,000 (including tax) shipping is free.",
#                                 "_key": "bc5ce50b3c0f"
#                             }
#                         ],
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "d37b14f71bc7",
#                         "markDefs": []
#                     },
#                     {
#                         "style": "normal",
#                         "_key": "4d137a892739",
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "marks": [],
#                                 "text": "",
#                                 "_key": "07600d642037",
#                                 "_type": "span"
#                             }
#                         ],
#                         "_type": "block"
#                     },
#                     {
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "About International Shipping",
#                                 "_key": "e05b50892982"
#                             }
#                         ],
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "f1f61b6dbb18"
#                     },
#                     {
#                         "_key": "fbc055ba113b",
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "Shipping charges are set per area and should be confirmed at the time of payment.",
#                                 "_key": "337741bcfabf"
#                             }
#                         ],
#                         "_type": "block",
#                         "style": "normal"
#                     },
#                     {
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "5c7595aca1fa",
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "(Currently, the areas available for international shipping are the U.S. and South Korea.)\n",
#                                 "_key": "6379a725ff42"
#                             }
#                         ]
#                     },
#                     {
#                         "_key": "68cfa210e629",
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "Since the product price is set including import duties, we will handle the payment of these duties.",
#                                 "_key": "608038000193"
#                             }
#                         ],
#                         "_type": "block",
#                         "style": "normal"
#                     },
#                     {
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "Shipping fees are set separately and must be paid in addition to the product price.\n",
#                                 "_key": "149d4ab1db43"
#                             }
#                         ],
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "2d22306dad65",
#                         "markDefs": []
#                     },
#                     {
#                         "style": "normal",
#                         "_key": "fcc6fd5f517d",
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "Purchased items will be shipped by Fedex.",
#                                 "_key": "6d3b8349bfd6"
#                             }
#                         ],
#                         "_type": "block"
#                     },
#                     {
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "b7407d2c5854",
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "marks": [],
#                                 "text": "No refunds will be made for refused shipments or other returns.\n",
#                                 "_key": "86085aa7befd",
#                                 "_type": "span"
#                             }
#                         ]
#                     },
#                     {
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "International shipping terms and conditions are subject to change.",
#                                 "_key": "27b68a37b073"
#                             }
#                         ],
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "547bf18653b7",
#                         "markDefs": []
#                     },
#                     {
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "fa106f92d8b8",
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "Please be aware of this in advance.",
#                                 "_key": "6e9a4cb3a97c"
#                             }
#                         ]
#                     }
#                 ],
#                 "returnPolicy": [
#                     {
#                         "_key": "1b9f5e7f80a9",
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "In any case, we cannot cancel any orders after they have been placed. We also cannot accept any returns for customer convenience.",
#                                 "_key": "80c52039883f"
#                             }
#                         ],
#                         "_type": "block",
#                         "style": "normal"
#                     },
#                     {
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "525d191974d7",
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "Please note that we will not be able to accept any refunds in the event that an order is returned without contacting us, or in the event that an order is returned or cancelled due to refusal to receive it.",
#                                 "_key": "b0e6d7569a51"
#                             }
#                         ]
#                     },
#                     {
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "_key": "8baf1303b9df",
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "However, we will accept returns and exchanges only if the product is damaged, defective, or misdelivered upon arrival. Please contact us at inventory@taigatakahashi.com within 7 days of receipt of the product. In this case, shipping costs will be borne by us."
#                             }
#                         ],
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "2a3493820b38"
#                     }
#                 ],
#                 "_updatedAt": "2024-12-05T00:05:13Z",
#                 "_createdAt": "2020-08-18T15:22:14Z",
#                 "_id": "siteGlobal",
#                 "_rev": "n10eAegrGspodtsQvVjHEJ",
#                 "defaultMeta": null,
#                 "content": {
#                     "_type": "globalContent",
#                     "metaInformation": {
#                         "_type": "metaCard",
#                         "metaDescription": "Taiga Takahashi Official Website . Archaeological practice in Clothing, Photography, Sculpture and Architecture. Based in New York and Kyoto.",
#                         "metaTitle": "Taiga Takahashi | Official Website and Online Store"
#                     }
#                 },
#                 "returnPolicy_jp": [
#                     {
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "\u3069\u306e\u3088\u3046\u306a\u5834\u5408\u3067\u3082\u3001\u3054\u6ce8\u6587\u5f8c\u306f\u4e00\u5207\u30ad\u30e3\u30f3\u30bb\u30eb\u304c\u3067\u304d\u307e\u305b\u3093\u3002\n\u307e\u305f\u3001\u304a\u5ba2\u69d8\u90fd\u5408\u306e\u8fd4\u54c1\u3082\u4e00\u5207\u53d7\u3051\u4ed8\u3051\u308b\u3053\u3068\u304c\u3067\u304d\u307e\u305b\u3093\u3002",
#                                 "_key": "a640cd72221c"
#                             }
#                         ],
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "a894ea76b924",
#                         "markDefs": []
#                     },
#                     {
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "5e5c11a8c611",
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "\u3054\u9023\u7d61\u306a\u304f\u8fd4\u54c1\u3055\u308c\u305f\u5834\u5408\u3084\u3001\u53d7\u53d6\u62d2\u5426\u306b\u3088\u308b\u8fd4\u54c1\u30fb\u30ad\u30e3\u30f3\u30bb\u30eb\u306e\u5834\u5408\u306f\u3001\u8fd4\u91d1\u3082\u53d7\u3051\u4ed8\u3051\u308b\u3053\u3068\u304c\u3067\u304d\u307e\u305b\u3093\u306e\u3067\u3042\u3089\u304b\u3058\u3081\u3054\u4e86\u627f\u304f\u3060\u3055\u3044\u3002",
#                                 "_key": "99325ed812b9"
#                             }
#                         ]
#                     },
#                     {
#                         "_type": "block",
#                         "style": "normal",
#                         "_key": "3555c12bd3ef",
#                         "markDefs": [],
#                         "children": [
#                             {
#                                 "_key": "65896a483213",
#                                 "_type": "span",
#                                 "marks": [],
#                                 "text": "\u4f46\u3057\u3001\u5546\u54c1\u5230\u7740\u6642\u306b\u65bc\u3051\u308b\u7834\u640d\u3084\u7455\u75b5\u3001\u8aa4\u9001\u304c\u3042\u3063\u305f\u5834\u5408\u306b\u9650\u308a\u8fd4\u54c1\u30fb\u4ea4\u63db\u3092\u304a\u53d7\u3051\u3044\u305f\u3057\u307e\u3059\u3002\n\u5546\u54c1\u5230\u7740\u304b\u30897\u65e5\u4ee5\u5185\u306b\u3001Inventory@taigatakahashi.com\u307e\u3067\u3054\u6ce8\u6587\u756a\u53f7\u3068\u8a73\u7d30\u3092\u304a\u77e5\u3089\u305b\u304f\u3060\u3055\u3044\u3002\n\u3053\u306e\u5834\u5408\u306e\u9001\u6599\u306f\u5f0a\u793e\u306b\u3066\u8ca0\u62c5\u3055\u305b\u3066\u3044\u305f\u3060\u304d\u307e\u3059\u3002"
#                             }
#                         ]
#                     }
#                 ],
#                 "social": null
#             },
#             "title": "Lot \u2116\u20097 Denim",
#             "store": {
#                 "gid": "gid://shopify/Collection/290460663974",
#                 "disjunctive": false,
#                 "slug": {
#                     "current": "lot-7-denim",
#                     "_type": "slug"
#                 },
#                 "sortOrder": "ALPHA_ASC",
#                 "rules": [
#                     {
#                         "condition": "Denim",
#                         "_type": "object",
#                         "column": "TAG",
#                         "_key": "9c55b070-7a33-5e3c-880c-70d9acc3a5b6",
#                         "relation": "EQUALS"
#                     },
#                     {
#                         "condition": "Online",
#                         "_type": "object",
#                         "column": "TAG",
#                         "_key": "26557fb0-0cd7-5247-8062-3ca1bda44088",
#                         "relation": "EQUALS"
#                     }
#                 ],
#                 "descriptionHtml": "",
#                 "id": 290460663974,
#                 "createdAt": "2022-09-07T23:40:33.000Z",
#                 "isDeleted": false,
#                 "title": "Lot \u2116\u20097 Denim"
#             },
#             "meta": null
#         }
#     },
#     "staticQueryHashes": [
#         "1546103458",
#         "2672830156",
#         "938548982"
#     ],
#     "slicesMap": {}
# }
